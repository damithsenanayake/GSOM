# %%
import numpy as np
import pandas as pd
from gsom_prune import GSOM
import matplotlib.pyplot as plt
from visualize import scatter_basic, scatter_gradient
from sklearn.manifold import TSNE, MDS, Isomap

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
spiral = pd.read_csv('~/data/spiral.csv', header=None)
X = np.array(spiral).astype(float)#[:, :2]
X += abs(np.amin(X))
X /= X.max()

# %%
X_r = X[np.random.permutation(X.shape[0])]

# %%
gsom = GSOM(dims=3, min_nodes=10, max_nodes = 1000, fd = 0.25, sf=0.3, radius=2.1,lr=1)

# %%
for i in range(25):
    print '\nbatch ', (i+1)
    gsom.train_batch(X=X_r, lr=0, iterations=1, prune=False)

grid, hits = gsom.predict(X)

plt.scatter(grid.T[0], grid.T[1], c = plt.cm.Set1(np.array(range(X.shape[0])).astype(float)/X.shape[0]), edgecolors='none')
# plt.plot(grid.T[0], grid.T[1], c = 'grey')
plt.show()
# Out:
# batch  1
#  epoch 1 / 1 :  100% : nodes - 4
# batch  2
#  epoch 1 / 1 :  100% : nodes - 12
# batch  3
#  epoch 1 / 1 :  100% : nodes - 24
# batch  4
#  epoch 1 / 1 :  100% : nodes - 40
# batch  5
#  epoch 1 / 1 :  100% : nodes - 60
# batch  6
#  epoch 1 / 1 :  100% : nodes - 84
# batch  7
#  epoch 1 / 1 :  100% : nodes - 112
# batch  8
#  epoch 1 / 1 :  100% : nodes - 144
# batch  9
#  epoch 1 / 1 :  100% : nodes - 180
# batch  10
#  epoch 1 / 1 :  100% : nodes - 220
# batch  11
#  epoch 1 / 1 :  100% : nodes - 264
# batch  12
#  epoch 1 / 1 :  100% : nodes - 312
# batch  13
#  epoch 1 / 1 :  100% : nodes - 364
# batch  14
#  epoch 1 / 1 :  100% : nodes - 420
# batch  15
#  epoch 1 / 1 :  100% : nodes - 480
# batch  16
#  epoch 1 / 1 :  100% : nodes - 544
# batch  17
#  epoch 1 / 1 :  100% : nodes - 612
# batch  18
#  epoch 1 / 1 :  100% : nodes - 684
# batch  19
#  epoch 1 / 1 :  100% : nodes - 760
# batch  20
#  epoch 1 / 1 :  100% : nodes - 840
# batch  21
#  epoch 1 / 1 :  100% : nodes - 924
# batch  22
#  epoch 1 / 1 :  100% : nodes - 1012
# batch  23
#  epoch 1 / 1 :  100% : nodes - 1104
# batch  24
#  epoch 1 / 1 :  100% : nodes - 1200
# batch  25
#  epoch 1 / 1 :  100% : nodes - 1300

# %%
plt.scatter(grid.T[0], grid.T[1], c = plt.cm.Set1(np.array(range(X.shape[0])).astype(float)/X.shape[0]), edgecolors='none')
plt.plot(grid.T[0], grid.T[1], c = 'grey')
plt.show()
